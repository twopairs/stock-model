# %%
# yahoo 에서 data 확보
# modeling을 종가로 try

import yfinance as yf

stock_id = "SSNLF"


data = yf.Ticker(stock_id)

# 종가만 포함하여 가져오기 (기본값)
hist_data = data.history()

# 특정 기간의 종가 데이터만 가져오기 (예: 2023년 1월 1일부터 현재까지)
hist_data_period = data.history(start="2023-01-01")

# print(hist_data.head())
# print(hist_data_period.head())

hist_data_period
# Out:
#                                    Open          High           Low  \
# Date
# 2023-01-03 00:00:00-05:00 -3.202941e+11 -3.202941e+11 -3.202941e+11
# 2023-01-04 00:00:00-05:00 -3.202941e+11 -3.202941e+11 -3.202941e+11
# 2023-01-05 00:00:00-05:00 -3.202941e+11 -3.202941e+11 -3.202941e+11
# 2023-01-06 00:00:00-05:00 -3.202941e+11 -3.202941e+11 -3.202941e+11
# 2023-01-09 00:00:00-05:00 -3.202941e+11 -3.202941e+11 -3.202941e+11
# ...                                 ...           ...           ...
# 2025-11-19 00:00:00-05:00  6.521000e+01  6.521000e+01  6.521000e+01
# 2025-11-20 00:00:00-05:00  6.521000e+01  6.521000e+01  6.521000e+01
# 2025-11-21 00:00:00-05:00  6.521000e+01  6.521000e+01  6.521000e+01
# 2025-11-24 00:00:00-05:00  6.521000e+01  6.521000e+01  6.521000e+01
# 2025-11-25 00:00:00-05:00  6.521000e+01  6.521000e+01  6.521000e+01
#
#                                   Close  Volume  Dividends  Stock Splits
# Date
# ...
